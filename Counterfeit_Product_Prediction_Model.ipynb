# %%
from Predictor import is_counterfeit

# %%
price = float(input("Price: "))
seller_reviews = int(input("Seller Reviews: "))
product_images = int(input("Number of Product Images: "))
description_length = float(input("Description Length: "))
shipping_time_days = float(input("Shipping Time (days): "))
domain_age_days = int(input("Domain Age (days): "))
views = int(input("Views: "))
purchases = int(input("Purchases: "))
warranty_months = float(input("Warranty (months): "))
brand_name = input("Brand Name: ")

result = is_counterfeit(price, seller_reviews, product_images, description_length,
                         shipping_time_days, domain_age_days, views, purchases,
                         warranty_months, brand_name)

print(result)
# Out:
# Price:  15
# Seller Reviews:  20
# Number of Product Images:  1
# Description Length:  40
# Shipping Time (days):  45
# Domain Age (days):  20
# Views:  500
# Purchases:  10
# Warranty (months):  0
# Brand Name:  Techcr0p
# {'prediction': 'COUNTERFEIT', 'counterfeit_probability': np.float64(88.0), 'brand_flagged_suspicious': True}

# %%
price = float(input("Price: "))
seller_reviews = int(input("Seller Reviews: "))
product_images = int(input("Number of Product Images: "))
description_length = float(input("Description Length: "))
shipping_time_days = float(input("Shipping Time (days): "))
domain_age_days = int(input("Domain Age (days): "))
views = int(input("Views: "))
purchases = int(input("Purchases: "))
warranty_months = float(input("Warranty (months): "))
brand_name = input("Brand Name: ")

result = is_counterfeit(price, seller_reviews, product_images, description_length,
                         shipping_time_days, domain_age_days, views, purchases,
                         warranty_months, brand_name)

print(result)
# Out:
# Price:  250
# Seller Reviews:  5000
# Number of Product Images:  6
# Description Length:  700
# Shipping Time (days):  3
# Domain Age (days):  2500
# Views:  3000
# Purchases:  400
# Warranty (months):  24
# Brand Name:  Apple
# {'prediction': 'GENUINE', 'counterfeit_probability': np.float64(15.0), 'brand_flagged_suspicious': False}

# %%
price = float(input("Price: "))
seller_reviews = int(input("Seller Reviews: "))
product_images = int(input("Number of Product Images: "))
description_length = float(input("Description Length: "))
shipping_time_days = float(input("Shipping Time (days): "))
domain_age_days = int(input("Domain Age (days): "))
views = int(input("Views: "))
purchases = int(input("Purchases: "))
warranty_months = float(input("Warranty (months): "))
brand_name = input("Brand Name: ")

result = is_counterfeit(price, seller_reviews, product_images, description_length,
                         shipping_time_days, domain_age_days, views, purchases,
                         warranty_months, brand_name)

print(result)
# Out:
# Price:  250
# Seller Reviews:  5000
# Number of Product Images:  6
# Description Length:  700
# Shipping Time (days):  3
# Domain Age (days):  2500
# Views:  3
# Purchases:  4
# Warranty (months):  1
# Brand Name:  @pple
# {'prediction': 'GENUINE', 'counterfeit_probability': np.float64(48.0), 'brand_flagged_suspicious': True}
